# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds=pd.read_csv('/content/Advertising.csv')
ds
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
ds.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
plt.style.use('ggplot')
fig, ax=plt.subplots(figsize=(9,6))
sns.scatterplot(x='TV', y='Sales',data=ds, ax=ax, color='purple')

# %%
ax.set_title('The relationship between TV advertising and sales',pad=20,size=18,color='black')
plt.savefig('scatterplot.png')

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,5.4))
plt.tight_layout(pad=5)
sns.distplot(ds['TV'],ax=ax[0])
ax[0].axvline(x=np.mean(ds['TV']), color='red',label='mean')
ax[0].axvline(x=np.median(ds['TV']), color='orange',label='median')
ax[0].set_ylabel('Frequency')
ax[0].set_title('Histogram of TV')
ax[0].legend(loc='upper right')
sns.distplot(ds['Sales'],ax=ax[1])
ax[1].axvline(x=np.mean(ds['Sales']), color='red',label='mean')
ax[1].axvline(x=np.median(ds['Sales']), color='orange',label='median')
ax[1].set_ylabel('Frequency')
ax[1].set_title('Histogram of Sales')
ax[1].legend(loc='upper right')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x=ds.iloc[:,0:-1]
x
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y=ds.iloc[:,0:-1]
y
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
x_train
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 116         117  139.2   14.3       25.6
# 138         139   43.0   25.9       20.5
# 155         156    4.1   11.6        5.7
# 82           83   75.3   20.3       32.5
# 160         161  172.5   18.1       30.7
# ..          ...    ...    ...        ...
# 58           59  210.8   49.6       37.7
# 21           22  237.4    5.1       23.5
# 49           50   66.9   11.7       36.8
# 64           65  131.1   42.8       28.9
# 68           69  237.4   27.5       11.0
#
# [160 rows x 4 columns]

# %%
x_test
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 56           57    7.3   28.1       41.4
# 37           38   74.7   49.4       45.7
# 67           68  139.3   14.5       10.2
# 79           80  116.0    7.7       23.1
# 80           81   76.4   26.7       22.3
# 188         189  286.0   13.9        3.7
# 183         184  287.6   43.0       71.8
# 10           11   66.1    5.8       24.2
# 128         129  220.3   49.0        3.2
# 62           63  239.3   15.5       27.3
# 65           66   69.0    9.3        0.9
# 17           18  281.4   39.6       55.8
# 133         134  219.8   33.5       45.1
# 195         196   38.2    3.7       13.8
# 146         147  240.1    7.3        8.7
# 38           39   43.1   26.7       35.1
# 173         174  168.4    7.1       12.8
# 149         150   44.7   25.8       20.6
# 93           94  250.9   36.5       72.3
# 29           30   70.6   16.0       40.8
# 0             1  230.1   37.8       69.2
# 2             3   17.2   45.9       69.3
# ...

# %%
y_train
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 116         117  139.2   14.3       25.6
# 138         139   43.0   25.9       20.5
# 155         156    4.1   11.6        5.7
# 82           83   75.3   20.3       32.5
# 160         161  172.5   18.1       30.7
# ..          ...    ...    ...        ...
# 58           59  210.8   49.6       37.7
# 21           22  237.4    5.1       23.5
# 49           50   66.9   11.7       36.8
# 64           65  131.1   42.8       28.9
# 68           69  237.4   27.5       11.0
#
# [160 rows x 4 columns]

# %%
y_test
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 56           57    7.3   28.1       41.4
# 37           38   74.7   49.4       45.7
# 67           68  139.3   14.5       10.2
# 79           80  116.0    7.7       23.1
# 80           81   76.4   26.7       22.3
# 188         189  286.0   13.9        3.7
# 183         184  287.6   43.0       71.8
# 10           11   66.1    5.8       24.2
# 128         129  220.3   49.0        3.2
# 62           63  239.3   15.5       27.3
# 65           66   69.0    9.3        0.9
# 17           18  281.4   39.6       55.8
# 133         134  219.8   33.5       45.1
# 195         196   38.2    3.7       13.8
# 146         147  240.1    7.3        8.7
# 38           39   43.1   26.7       35.1
# 173         174  168.4    7.1       12.8
# 149         150   44.7   25.8       20.6
# 93           94  250.9   36.5       72.3
# 29           30   70.6   16.0       40.8
# 0             1  230.1   37.8       69.2
# 2             3   17.2   45.9       69.3
# ...

# %%
x_train=x_train.astype(int)
y_train=y_train.astype(int)
x_test=x_test.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
Sc=StandardScaler()

# %%
x_train_scaled=Sc.fit_transform(x_train)
x_test_scaled=Sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test_scaled)
print("Intercept",lr.intercept_)
print("Slope",lr.coef_)
# Out:
# Intercept [102.38125 146.5      22.64375  29.85   ]
# Slope [[ 5.61915109e+01  3.02703815e-15  2.31480235e-15  7.10487093e-16]
#  [-7.43087963e-15  8.55160073e+01  3.55271368e-15  0.00000000e+00]
#  [-1.04874861e-17 -8.88178420e-16  1.49934764e+01  8.88178420e-16]
#  [-1.71088439e-15  0.00000000e+00  1.50990331e-14  2.18709853e+01]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9880846969823762

# %%
plt.scatter(y_test,y_pred,c='g')

# %%
g=sns.regplot("TV","Sales",data=ds,ci=None,scatter_kws={'color':'red','s':9})
g.set_title("Model TV vs Sales")
g.set_xlabel("TV")
g.set_ylabel("Sales")
import matplotlib.pyplot as plt
plt.xlim(-10,310)
plt.ylim(0,);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
